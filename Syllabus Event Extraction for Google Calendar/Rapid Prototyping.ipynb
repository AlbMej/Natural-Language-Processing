# %%
# Perform standard imports
import spacy
nlp = spacy.load('en_core_web_lg')

# %%
import PyPDF2
import pdftotext
import os
import re
import subprocess
import pprint
import datefinder

# %%
import re
from spacy import displacy

# %%
class SyllabusParser:
    """"""
    def __init__(self, syllabus, html = False):
        
#         with open(syllabus, "rb") as file:
#             self.pdf = pdftotext.PDF(file)
#         self.pdf = pdftotext.PDF(open(syllabus, 'rb'))
            
        self.syllabus = syllabus # Path to syllabus
        self.pages = {} #{Page: [Sentences]}
        self.numPages = len(syllabus)
        if html:
            self.addHTML(syllabus)
            #self.addEventsPg(1)
    
    def addHTML(self, sentences):
        self.pages[0] = sentences 
    
    def parse(self, end = None):
        """
        Method for extracting text from pdf files
        Parameters: 
            file (PDF): pdf file
            end (0-n): Parse up to this page
        Returns: 
            text (String): extracted text of document line by line       
        """
        #if end is None: end = self.numPages
        pdf = pdftotext.PDF(open(self.syllabus, 'rb'))
        end = len(pdf)
        
        allText = []
        for i in range(end):
            sentences = []
            lines = []
            page = pdf[i].splitlines()
            for sentence in page:
                # Remove all extra spacing 
                lines.append(sentence.split())
                
            for line in lines:
                # Add appropriate spacing
                sentences.append(" ".join(line))
                allText.append(" ".join(line))
            self.pages[i] = sentences   
            
        return allText
    
    def getInstructorInfo(self):
        pdf = pdftotext.PDF(open(self.syllabus, 'rb'))
        # Instructor 
        pg1 = pdf[0]
        pass
    
    def addHTMLEvents(self, num):
        """
        TODO: Add support for quizzes, hw, etc. 
        """
        # Adds exam to date
        toAdd = {} #"{Event: Time}"
        exs = {'exam', 'Exam', 'Test', 'test'}
        text = self.pages[num]
        aText = " ".join(self.pages[num])
        doc = nlp(aText)
        for sentence in text:
            doc = nlp(sentence)
            ents = [ent for ent in doc.ents]
            for ent in ents:
                if ent.label_ == 'DATE':
                    #print(sentence)
                    if 'Exam' in sentence:
                        toAdd[ent] = ('Exam', sentence)
        return toAdd

    
    def addEventsPg(self, num):
        """
        TODO: Add support for quizzes, hw, etc. 
        """
        # Adds exam to date
        toAdd = {} #"{Event: Time}"
        exs = {'exam', 'Exam', 'Test', 'test'}
        pdf = pdftotext.PDF(open(self.syllabus, 'rb'))
        text = self.pages[num]
        aText = " ".join(self.pages[num])
        doc = nlp(aText)
        for sentence in text:
            doc = nlp(sentence)
            #print("Doc",doc)
            ents = [ent for ent in doc.ents]
            for ent in ents:
                
#                 print("***", sentence,"sents")
                if ent.label_ == 'DATE':
                    if 'Exam' in sentence:
#                         print(sentence)
#                         print(ents,"ents", "ENT:", ent)
                        toAdd[ent] = ('Exam', sentence)
#                         print(toAdd, "TO")
                    
#                     examEvent = extractInfo.exams(sentence)
#                     if len(examEvent) > 0:
#                         event = examEvent[0]
#                         time = ent.label_
#                         toAdd[event] = time
        return toAdd
            
#         for ent in doc.ents:
#             print(ent, ent.text, ent.label_)
#             if ent.label_ == 'DATE':
#                 print(ent, "*")
                
                #print(ent.text, ent.label_)
                #return ent.text
#         for sentence in sentences:
#             doc = nlp(sentence)
#         print(text)

# %%
# sample1 = "./Syllabuses/MATH 2210Q Fall 2017 Topics.pdf"
# p = PDFSyllabusParser(sample1)
# print(p.parse())
bio = "./Syllabuses/BIOL_1107_Fall_2016_Syllabus.pdf"
mys = SyllabusParser(bio)
mys.parse()
print(mys.addEventsPg(1))

data = mys.addEventsPg(1)

for eventDate in data:
    summary = data[eventDate][0]
    description = data[eventDate][1]
    print(eventDate)
    date = list(datefinder.find_dates(eventDate.text))
    if len(date) == 0:
        print('Not a vaild date')
        break
    print(summary, description, date)
# Out:
# {Monday September 19th, 2016: ('Exam', 'Exam I: Monday September 19th, 2016, (Testing Center)'), Friday October 7th, 2016: ('Exam', 'Exam II: Friday October 7th, 2016, (Testing Center)'), Monday October 24th, 2016: ('Exam', 'Exam III: Monday October 24th, 2016, (Testing Center)'), Tuesday November 15th, 2016: ('Exam', 'Exam IV: Tuesday November 15th, 2016, (Testing Center)'), testing days: ('Exam', 'Exam times: During the semester, exams are held on testing days from 8:00AM on the hour')}
# Monday September 19th, 2016
# Exam Exam I: Monday September 19th, 2016, (Testing Center) [datetime.datetime(2016, 9, 19, 0, 0)]
# Friday October 7th, 2016
# Exam Exam II: Friday October 7th, 2016, (Testing Center) [datetime.datetime(2016, 10, 7, 0, 0)]
# Monday October 24th, 2016
# Exam Exam III: Monday October 24th, 2016, (Testing Center) [datetime.datetime(2016, 10, 24, 0, 0)]
# Tuesday November 15th, 2016
# ...

# %%
# from dateutil.parser import *
# from dateutil.tz import *
# from datetime import *
# TZOFFSETS = {"BRST": -10800}
# BRSTTZ = tzoffset(-10800, "BRST")
# DEFAULT = datetime(2003, 9, 25)

# parse("Thu Sep 25 10:36:28 BRST 2003", tzinfos=TZOFFSETS)
# #datetime.datetime(2003, 9, 25, 10, 36, 28, tzinfo=tzoffset('BRST', -10800))

nlph = "Natural Language Processing with Watson.html"
f = open(nlph, "r")
x = cleanMe(f)

sentences = str(x).replace(u'\xa0', u' ').split("\n")
sentence = " ".join(words)

#print(sentence)
print(extractInfo.emailAddresses(sentence))

mys = SyllabusParser(sentences, True)
data = mys.addHTMLEvents(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-121f56509061> in <module>
#      11 nlph = "Natural Language Processing with Watson.html"
#      12 f = open(nlph, "r")
# ---> 13 x = cleanMe(f)
#      14
#      15 sentences = str(x).replace(u'\xa0', u' ').split("\n")
#
# NameError: name 'cleanMe' is not defined

# %%
sample1 = "./Syllabuses/MATH 2210Q Fall 2017 Topics.pdf"
# Load your PDF
with open(sample1, "rb") as f:
    pdf = pdftotext.PDF(f)

# How many pages?
#print(len(pdf))

# # Iterate over all the pages
# for page in pdf:
#     print(page)

pdf = pdf[0].splitlines()

lines = []
sentences = []
for i in pdf:
    lines.append(i.split())
#pprint.pprint(lines)

for line in lines:
    sentences.append(" ".join(line))

#print(sentences)

# %%
# for sentence in sentences:
#     displacy.render(nlp(sentence), style = 'ent', jupyter = True)

# %%
mys = SyllabusParser(bio)
mys.parse()
#pprint.pprint(mys.pages)
print("***", mys.numPages)
pg1 = mys.pages[0]
# for sentence in pg1:
#     displacy.render(nlp(sentence), style = 'ent', jupyter = True)
displacy.render(nlp(pg1[3]), style = 'ent', jupyter = True)
# Out:
# *** 45
# <div class="entities" style="line-height: 2.5; direction: ltr">Section 001: (9:05-9:55AM, Mon, Wed and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Fri
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# )</div>

# %%
sample1 = "./Syllabuses/MATH 2210Q Fall 2017 Topics.pdf"
# Load your PDF
with open(bio, "rb") as f:
    pdf = pdftotext.PDF(f)

# How many pages?
#print(len(pdf))

# # Iterate over all the pages
# for page in pdf:
#     print(page)

# print(pdf[0])
pdf = pdf[5].splitlines()

lines = []
sentences = []
for i in pdf:
    lines.append(i.split())
#pprint.pprint(lines)

for line in lines:
    sentences.append(" ".join(line))

#print(sentences)

# %%
class extractInfo:
    @classmethod
    def professorName(cls, text):
        # Using __ to extract the professor's name from text 
        salutations = ["Prof.", "Prof", "Dr.", "Dr", "Instructor"]
        doc = nlp(u"{}".format(text))
        for ent in doc.ents:
            name = ent.text.split()
            if ent.label_ == "PERSON" and name[0] in salutations:
                return ent.text
            
    @classmethod
    def phoneNumbers(cls, text):
        phoneNbrs = []
        # Regex pattern to extract phone numbers from text 
        #pattern = r'\s*\({0,1}(\d{3})-*\s*\){0,1}\s*(\d{3})-*\s*(\d{4})\n{0,1}'
        pattern = r'\({0,1}(\d{3})-*\s*\){0,1}\s*(\d{3})-*\s*(\d{4})\n{0,1}'
        found = re.findall(pattern, text)
        for nbr in found:
            group1, group2, group3 = nbr
            phoneNbrs.append(" ".join([group1, group2, group3]))
        return phoneNbrs
            
    @classmethod
    def emailAddresses(cls, text):
        """
        Finds phone numbers of the form:
            111-111-1111, 111 111 1111, (111)111-1111, (111) 111-111, (111) 111 111
        """
        # Regex pattern to extract email addresses from text 
        pattern = r'[a-zA-Z0-9-_.]+@[a-zA-Z0-9-_.]+'
        return re.findall(pattern, str(text))
    
    @classmethod
    def exams(cls, text):
        #pattern = r"Exam\s*\:*[0-9]+"
        events = []
        pattern = r"Exam\s*[A-Za-z0-9_-]*$"
#         return re.findall(pattern, str(text))
        words = text.split()
        print("Split", words)
        for word in words:
            x = re.findall(pattern, str(text))
            if len(x) > 0: events.append(x[0])
        return events

# %%
def print_fine_pos(token):
    return (token.tag_)

def pos_tags(sentence):
    sentence = u'{}'.format(s)
    tokens = nlp(sentence)
    tags = []
    for tok in tokens:
        tags.append((tok,print_fine_pos(tok)))
    return tags

# %%
def expand_person_entities(doc):
    new_ents = []
    for ent in doc.ents:
        print(ent.text)
        if ent.label_ == "PERSON" and ent.start != 0:
            prev_token = doc[ent.start - 1]
            if ent.start.text in ("Dr", "Dr.", "Mr", "Mr.", "Ms", "Ms.", "Mrs", "Mrs.","Prof", "Prof.", "Instructor:"):
                new_ent = Span(doc, ent.start - 1, ent.end, label=ent.label)
                new_ents.append(new_ent.text)
        else:
            new_ents.append(ent)
    doc.ents = new_ents
    return doc

# Add the component after the named entity recognizer
# nlp.add_pipe(expand_person_entities, after='ner')

# %%
text = " ".join(mys.parse())
exs = ["914 338 5800", "(914) 338 5800", "(914) 338-5800", "914-338-5800", "(914)338 5800"]
nameexs = ["Alberto Mejia", "Dr. Thomas D. Abbott", "Thomas D. Abbott", "Mr. Thomas D. Abbott", "Ms. Alexa", "Dr. Thomas", "Instructor: Dr. Thomas"] 

# for ex in nameexs:
#     ex = nlp(ex)
#     print([(ent.text, ent.label_) for ent in ex.ents])
    
#     print(extractInfo.professorName(ex))

# print([(ent.text, ent.label_) for ent in nlpdoc.ents])
print(extractInfo.emailAddresses(text))
print(extractInfo.phoneNumbers(text))
print(extractInfo.professorName(text))
# Out:
# ['thomas.abbott@uconn.edu']
# ['860 486 2939']
# None

# %%
pdf = pdftotext.PDF(open(bio, 'rb'))
print(pdf[1])
pg1 = pdf[1].splitlines()

# print(pg1)
lines = []
sentences = []
for sentence in pg1:
    # Remove all extra spacing 
    lines.append(sentence.split())

for line in lines:
    # Add appropriate spacing
    sentences.append(" ".join(line))
#print(sentences)

for s in sentences:
    print("Sentence:", s)
    displacy.render(nlp(s), style = 'dep', jupyter = True)

for s in sentences:
    print()
    print(pos_tags(s))
    print()
# Out:
# Exams and Grades:
#     Exam dates: There will be five exams, each covering 1/5 of the course material. Exams will
#     be held at the Testing Center unless otherwise noted. Check the HuskyCT lecture site for
#     announcements. Exam grades will be posted to your HuskyCT lecture section page.
#       Exam I: Monday September 19th, 2016, (Testing Center)
#       Exam II: Friday October 7th, 2016, (Testing Center)
#       Exam III: Monday October 24th, 2016, (Testing Center)
#       Exam IV: Tuesday November 15th, 2016, (Testing Center)
#       Exam V: During Final Exam Week, taken in class/lecture hall as hard copy.
#     Exam format, content and point value: Exam format, content and point value: All five
#     exams will consist of 50 questions in multiple-choice format. Students must bring TWO #2
#     pencils to each exam and a photo ID. *Exams will be primarily based on lecture material,
# ...

# %%
def show_ents(doc):
    if doc.ents:
        for ent in doc.ents:
            print(ent.text+' - '+ent.label_+' - '+str(spacy.explain(ent.label_)))
    else:
        print('No named entities found.')

def get_ents(doc, entType = None):
    allEntities = []
    if doc.ents:
        for ent in doc.ents:
            if ent.label_ != entType and entType is not None:
                continue
            else:
                allEntities.append((ent.text, ent.label_+' - '+str(spacy.explain(ent.label_))))
        return allEntities
    else:
        return 'No named entities found.'

# %%
from spacy.pipeline import EntityRecognizer
ner = EntityRecognizer(nlp.vocab)
ner.add_label("INSTRUCTOR")

# %%
x = nlp(u'I am Instructor: Mrs. Thomas D. Abbott.')

# %%
per = show_ents(x)
# Out:
# Thomas D. Abbott - PERSON - People, including fictional

# %%
phrase_list = ['Dr. Abbott', 'Dr. Thomas Abbott', 'Dr. Thomas D. Abbot', 'Prof. Abbott', 'Mr. Samuel Johnson', 'Mrs. Anne'
               'Prof. Thomas D Abbott', 'Professor Abbott', 'Professor Thomas D. Abbott', 'Instructor: Dr. Thomas D. Abbott',
               'Instructor: Renji Chen', 'Instructor: Arthur J. Parzygnat']

# %%
# from spacy.tokens import Doc
# doc = nlp(nlp.vocab, words=["Facebook", "released", "React", "in", "2014"])
# gold = GoldParse(doc, entities=["U-ORG", "O", "U-TECHNOLOGY", "O", "U-DATE"])

# %%
"""A simple example of extracting relations between phrases and entities using
spaCy's named entity recognizer and the dependency parse. Here, we extract
money and currency values (entities labelled as MONEY) and then check the
dependency tree to find the noun phrase they are referring to – for example:
$9.4 million --> Net income.

Compatible with: spaCy v2.0.0+
Last tested with: v2.1.0
"""

import plac

TEXTS = [
    "Net income was $9.4 million compared to the prior year of $2.7 million.",
    "Revenue exceeded twelve billion dollars, with a loss of $1b.",
]


@plac.annotations(
    model=("Model to load (needs parser and NER)", "positional", None, str)
)
def main(model="en_core_web_sm"):
    nlp = spacy.load(model)
    print("Loaded model '%s'" % model)
    print("Processing %d texts" % len(TEXTS))

    for text in TEXTS:
        doc = nlp(text)
        relations = extract_currency_relations(doc)
        for r1, r2 in relations:
            print("{:<10}\t{}\t{}".format(r1.text, r2.ent_type_, r2.text))


def extract_currency_relations(doc):
    # merge entities and noun chunks into one token
    spans = list(doc.ents) + list(doc.noun_chunks)
    for span in spans:
        span.merge()

    relations = []
    for money in filter(lambda w: w.ent_type_ == "MONEY", doc):
        if money.dep_ in ("attr", "dobj"):
            subject = [w for w in money.head.lefts if w.dep_ == "nsubj"]
            if subject:
                subject = subject[0]
                relations.append((subject, money))
        elif money.dep_ == "pobj" and money.head.dep_ == "prep":
            relations.append((money.head.head, money))
    return relations

plac.call(main)
# Out:
# usage: ipykernel_launcher.py [-h] [model]
# ipykernel_launcher.py: error: unrecognized arguments: -f
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /home/alberto/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3304: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
x = ["Exam 1", "Exam1", "Exam 1:", "Exam 1 and Exam 2", "Exam II:", "Exam III: Monday October 24th, 2016, (Testing Center)"]
pattern = r"Exam\s*[A-Za-z0-9_-]*\:*$"#r"Exam\s*[A-Za-z0-9_-]*\s*$"
#pattern = r"\b((Exam|exam\.)[\s]+[IVXLCDM]+\b)"
for i in x:
    print(re.findall(pattern, str(i)))
    #print(extractInfo.exams(i))
# Out:
# ['Exam 1']
# ['Exam1']
# ['Exam 1:']
# ['Exam 2']
# ['Exam II:']
# []

# %%
sentence = "Exam II: Friday October 7th, 2016, (Testing Center)"
doc = nlp(sentence)
print("Doc",doc)
ents = [ent for ent in doc.ents]
print(ents)
for ent in ents:
    if ent.label_ == 'DATE':
        print(ent, ent.label_)
        examEvent = extractInfo.exams(sentence)
        print(examEvent, "*")
        if len(examEvent) > 0:
            event = examEvent[0]
            time = ent.label_
# Out:
# Doc Exam II: Friday October 7th, 2016, (Testing Center)
# [Friday October 7th, 2016, Testing Center]
# Friday October 7th, 2016 DATE
# Split ['Exam', 'II:', 'Friday', 'October', '7th,', '2016,', '(Testing', 'Center)']
# [] *

# %%
#!/usr/bin/python
from bs4 import BeautifulSoup
import re

def soupify(html_file):
    return BeautifulSoup(html_file)
    
def pretty_print(soup):    
    print(soup.prettify())
    
def find_attribute(soup, attr, search_str):
    return soup.find_all(attrs = {attr : re.compile(search_str)})

# if __name__ == '__main__':
#     with open('Natural Language Processing with Watson.html') as file:
#         soup = soupify(file)
#         pretty_print(soup)
#         elements = find_attribute(soup, 'style', r'Bold')
#         for element in elements:
#             print(element)

# %%
from lxml import html
from lxml.html.clean import Cleaner
from xml.etree import ElementTree as etree
from lxml.html import fromstring

def clean_list(in_list):
    """
    Remove special symbols on each element in the list
    Input: list
    Output: list with cleaned elements
    """
    return [re.sub('[\r\n\t ]+', ' ', el.strip()) for el in in_list if re.sub('[\r\n\t ]+', '', el)]

def html(path):
    """
    Method for extracting text data from html files
    Input: full path to html file
    Output: extracted text
    """
    fh = open(os.path.join(path), 'r')
    etree = fromstring(Cleaner(style=True).clean_html(fh.read()))
    text = ' '.join(clean_list(etree.xpath('//text()')))
    return text

# %%
x = html('Natural Language Processing with Watson.html')

# %%
#displacy.render(nlp(x), style = 'ent', jupyter = True)

# %%
nlph = "Natural Language Processing with Watson.html"
f = open(nlph, "r")
f_lines = list(f)
for line in f_lines:
    line = BeautifulSoup(line)
    #print(line.get_text())

# %%
test = "Friday October 7th, 2016"
m = datefinder.find_dates("testing days")
print(m)
y = list(m)
print(y)
y[0].day
# Out:
# <generator object DateFinder.find_dates at 0x7fb383de2de0>
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-45fbe3d51073> in <module>
#       4 y = list(m)
#       5 print(y)
# ----> 6 y[0].day
#
# IndexError: list index out of range

# %%
def cleanMe(html):
    soup = BeautifulSoup(html) # create a new bs4 object from the html data loaded
    for script in soup(["script", "style"]): # remove all javascript and stylesheet code
        script.extract()
    # get text
    text = soup.get_text()
    # break into lines and remove leading and trailing space on each
    lines = (line.strip() for line in text.splitlines())
    # break multi-headlines into a line each
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    # drop blank lines
    text = '\n'.join(chunk for chunk in chunks if chunk)
    return text

f = open(nlph, "r")
x = cleanMe(f)

table_words = ['topics', 'sections', 'reading', 'lecture', 'assignment', 'date', 'week', 'sections', 'schedule']


matches = datefinder.find_dates(x)
a  ="9/18 11:59 pm"

for match in matches:
    print(match)

# %%
from spacy.tokens.doc import Doc
from spacy.gold import GoldParse
from spacy.pipeline.pipes import EntityRecognizer

doc = Doc(nlp.vocab, words = [u'01/10', u'01/14', u'01/24', u'01/24', u'01/31', u'01/28 '])
gold = GoldParse(doc, entities = [u'U-DATE', u'U-DATE', u'U-DATE', u'U-DATE', u'U-DATE', u'U-DATE'])
nlp.entity.update(doc, gold)
# ner = EntityRecognizer(nlp.vocab, entity_types=['DATE'])
# ner.update(doc, gold)

# from spacy.tokens import Doc
# doc = nlp(nlp.vocab, words=["Facebook", "released", "React", "in", "2014"])
# gold = GoldParse(doc, entities=["U-ORG", "O", "U-TECHNOLOGY", "O", "U-DATE"])
# Out:
# {'ner': 8.029124081134796}

# %%
x = nlp(x)
displacy.render(x, style = 'ent', jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Natural Language Processing with Watson Natural Language Processing Time :
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Mondays
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  10am-11:20am
# ...

# %%
for i in x.sents:
    words = str(i).replace(u'\xa0', u' ').split("\n")
    setence = " ".join(words)
    print("words", words)
    print("ents", i.ents)
    if len(i.ents) > 0: 
        for ent in i.ents:
            #print("**", ent.label_)
            if ent.label_ == 'DATE':
                matches = datefinder.find_dates(str(i))
#                 for i in matches: 
#                     print(i)
                print((list(matches)), i)
                print("matches", [i for i in matches])
            if ent.text == 'PERSON':
                pass
    print()
# Out:
# words ['Natural Language Processing with Watson Natural Language Processing Time :']
# ents []
#
# words ['Mondays and Thursday 10am-11:20am']
# ents [Mondays, Thursday]
# [datetime.datetime(2019, 5, 2, 10, 0, tzinfo=tzoffset(None, -40800))] Mondays and Thursday 10am-11:20am
# matches []
# [datetime.datetime(2019, 5, 2, 10, 0, tzinfo=tzoffset(None, -40800))] Mondays and Thursday 10am-11:20am
# matches []
#
# words ['Place :']
# ents [Place]
#
# words ['Carnegie 113 Instructor:']
# ents [113]
#
# words ['Prof. Heng Ji (Email: jih@rpi.edu ;']
# ents [Heng Ji]
#
# words ['Office: Room 2148, Winslow Building; Office hours: 9:30am-10amm Mondays and Thursdays in classroom)']
# ents [Office, Winslow Building, Office hours, Mondays, Thursdays]
# ...

# %%
for i in x.sents:
    if
# Out:
#   File "<ipython-input-37-16ef60f86f88>", line 2
#     if
#        ^
# SyntaxError: invalid syntax

# %%
def remove_html_markup(s):
    tag = False
    quote = False
    out = ""

    for c in s:
            if c == '<' and not quote:
                tag = True
            elif c == '>' and not quote:
                tag = False
            elif (c == '"' or c == "'") and tag:
                quote = not quote
            elif not tag:
                out = out + c

    return out

# def clean_me(html):
#     soup = BeautifulSoup(html)
#     for s in soup(['script', 'style']):
#         s.decompose()
#     return ' '.join(soup.stripped_strings)

# # f = open(nlph, "r")
# # f_lines = list(f)
# # for line in f_lines:
# #     print(clean_me(line))

# for i in x.ents:
#     print(i)

# x = html(nlph)
# # print(x)

# f = open(nlph, "r")
# f_lines = list(f)
# x = []
# for line in f_lines:
#     x.append(remove_html_markup(line))

# print("".join(x))

# f = open(nlph, "r")
# f_lines = list(f)
# for line in f_lines:
#     print(cleanMe(line))

# %%
bio = "./Syllabuses/BIOL_1107_Fall_2016_Syllabus.pdf"
mys = SyllabusParser(bio)
mys.parse()
print(mys.addEventsPg(1))
# Out:
# {Monday September 19th, 2016: ('Exam', 'Exam I: Monday September 19th, 2016, (Testing Center)'), Friday October 7th, 2016: ('Exam', 'Exam II: Friday October 7th, 2016, (Testing Center)'), Monday October 24th, 2016: ('Exam', 'Exam III: Monday October 24th, 2016, (Testing Center)'), Tuesday November 15th, 2016: ('Exam', 'Exam IV: Tuesday November 15th, 2016, (Testing Center)'), testing days: ('Exam', 'Exam times: During the semester, exams are held on testing days from 8:00AM on the hour')}

# %%
sent = "I shot an elephant"
rsent = "Exam one is on Monday September 19th, 2016 (Testing Center)."
sent = "Exam one: Monday September 19th, 2016, (Testing Center)."
doc0 = nlp(rsent)

doc=nlp(sent)

sub_toks = [tok for tok in doc if (tok.dep_ == "nsubj") ]

#print(sub_toks)

# %%
displacy.render(nlp(rsent), style = 'dep', jupyter = True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0cb5b70d91424535be8bf3e9790419a0-0" class="displacy" width="1800" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Exam</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">is</tspan>
# ...
